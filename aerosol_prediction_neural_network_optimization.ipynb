# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
import numpy as np
import os
import tifffile as tiff
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Input, Concatenate, BatchNormalization, Dropout, GlobalAveragePooling2D, Add, LeakyReLU
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, LearningRateScheduler
from tensorflow.keras.initializers import HeNormal, HeUniform
import tensorflow as tf
from tensorflow.keras.optimizers import Adam, RMSprop, Nadam

# tf.keras.backend.clear_session()

print("split started")
# Load the dataset
df = pd.read_csv("datasets/train.csv")

print(f'Number of features: {df.shape[1]}')
print(f'Number of instances: {df.shape[0]}')
df.head()

# Preprocess numerical data
numerical_features = df[['elevation', 'ozone', 'NO2', 'azimuth', 'zenith', 'incidence_azimuth', 'incidence_zenith']]

# Numerical data scaling
scaler = StandardScaler()
numerical_features = scaler.fit_transform(numerical_features)

# Function to load and preprocess image data
def load_and_preprocess_image(filepath):
    img = tiff.imread(filepath)
    img_array = np.array(img)
    img_array = img_array / 65535.0   # Normalize pixel values
    return img_array

# Load image data
image_data = np.array([load_and_preprocess_image(os.path.join('./train/', filename)) for filename in df['file_name_l1']])

# Target variable
target = df['value_550'].values

# Split data into training, validation, and testing sets without stratification
from sklearn.model_selection import train_test_split

X_train_num, X_temp_num, X_train_img, X_temp_img, y_train, y_temp = train_test_split(numerical_features, image_data, target, test_size=0.3, random_state=42)
X_val_num, X_test_num, X_val_img, X_test_img, y_val, y_test = train_test_split(X_temp_num, X_temp_img, y_temp, test_size=0.5, random_state=42)

print("split done")

# Define the CNN and dense model
class AOTModel:
    def __init__(self, image_shape=(19, 19, 13), num_numerical_features=7):
        # Image processing Neural Network
        self.image_input = Input(shape=image_shape)
        initializer = HeUniform()
        
        image_processing_network = Conv2D(32, (3, 3), kernel_regularizer=l2(0.01), kernel_initializer=initializer)(self.image_input)
        image_processing_network = BatchNormalization()(image_processing_network)
        image_processing_network = LeakyReLU()(image_processing_network)
        image_processing_network = MaxPooling2D((2, 2))(image_processing_network)
        image_processing_network = Dropout(0.25)(image_processing_network)

        image_processing_network = Conv2D(64, (3, 3), kernel_regularizer=l2(0.01), kernel_initializer=initializer)(image_processing_network)
        image_processing_network = BatchNormalization()(image_processing_network)
        image_processing_network = LeakyReLU()(image_processing_network)
        image_processing_network = MaxPooling2D((2, 2))(image_processing_network)
        image_processing_network = Dropout(0.25)(image_processing_network)

        image_processing_network = Conv2D(128, (3, 3), kernel_regularizer=l2(0.01), kernel_initializer=initializer)(image_processing_network)
        image_processing_network = BatchNormalization()(image_processing_network)
        image_processing_network = LeakyReLU()(image_processing_network)
        image_processing_network = GlobalAveragePooling2D()(image_processing_network)
        image_processing_network = Dropout(0.5)(image_processing_network)

        # Residual connection
        # residual = Conv2D(128, (1, 1), kernel_regularizer=l2(0.01), kernel_initializer=initializer)(self.image_input)
        # residual = BatchNormalization()(residual)
        # residual = GlobalAveragePooling2D()(residual)
        # image_processing_network = Add()([image_processing_network, residual])

        # Numerical processing Neural Network
        self.numerical_input = Input(shape=(num_numerical_features,))
        numerical_processing_network = Dense(64, activation='relu', kernel_initializer=initializer)(self.numerical_input)
        numerical_processing_network = BatchNormalization()(numerical_processing_network)
        numerical_processing_network = Dropout(0.5)(numerical_processing_network)
        
        numerical_processing_network = Dense(128, activation='relu', kernel_initializer=initializer)(numerical_processing_network)
        numerical_processing_network = BatchNormalization()(numerical_processing_network)
        numerical_processing_network = Dropout(0.5)(numerical_processing_network)

        numerical_processing_network = Dense(64, activation='relu', kernel_initializer=initializer)(numerical_processing_network)
        numerical_processing_network = BatchNormalization()(numerical_processing_network)
        numerical_processing_network = Dropout(0.5)(numerical_processing_network)
        
        # Concatenation of both networks
        aot_network = Concatenate()([image_processing_network, numerical_processing_network])
        aot_network = Dense(64, activation='relu', kernel_initializer=initializer)(aot_network)
        aot_network = Dropout(0.5)(aot_network)
        aot_network = Dense(1, kernel_initializer=initializer)(aot_network)

        self.aot_network_arquitecture = aot_network
        del image_processing_network, numerical_processing_network, aot_network

    def model(self, learning_rate=0.001, optimizer_choice='adam'):
        model = Model(inputs=[self.image_input, self.numerical_input], outputs=self.aot_network_arquitecture)
        
        if optimizer_choice == 'adam':
            optimizer = Adam(learning_rate=learning_rate, clipnorm=1.0)
        elif optimizer_choice == 'rmsprop':
            optimizer = RMSprop(learning_rate=learning_rate, clipnorm=1.0)
        elif optimizer_choice == 'nadam':
            optimizer = Nadam(learning_rate=learning_rate, clipnorm=1.0)
        else:
            optimizer = Adam(learning_rate=learning_rate, clipnorm=1.0)
        
        model.compile(optimizer=optimizer, loss='mean_absolute_error', metrics=['mae'])
        return model

# Instantiate the model with a chosen optimizer
model = AOTModel().model(learning_rate=0.0001, optimizer_choice='adam')

# Define callbacks
def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * np.exp(-0.1)

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
# lr_scheduler = LearningRateScheduler(scheduler)

print("starting training")
# Train the model
history = model.fit(
    [X_train_img, X_train_num], y_train,
    validation_data=([X_val_img, X_val_num], y_val),
    epochs=200,
    batch_size=32,
    callbacks=[early_stopping, reduce_lr],
    verbose=1
)

model.save('aot_model.keras')

# Evaluate the model
val_loss, val_mae = model.evaluate([X_val_img, X_val_num], y_val)
print(f'Validation MAE: {val_mae}')

# Evaluate on test set
test_loss, test_mae = model.evaluate([X_test_img, X_test_num], y_test)
print(f'Test MAE: {test_mae}')
# Out:
# 2024-06-23 23:10:34.655717: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-23 23:10:36.070241: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# split started
# Number of features: 10
# Number of instances: 10438
# split done
# 2024-06-23 23:10:50.024772: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10689 MB memory:  -> device: 0, name: NVIDIA TITAN V, pci bus id: 0000:5e:00.0, compute capability: 7.0
# 2024-06-23 23:10:50.025414: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 10689 MB memory:  -> device: 1, name: NVIDIA TITAN V, pci bus id: 0000:86:00.0, compute capability: 7.0
# starting training
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1719180657.071169 1786170 service.cc:145] XLA service 0x7f783401fa60 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1719180657.071210 1786170 service.cc:153]   StreamExecutor device (0): NVIDIA TITAN V, Compute Capability 7.0
# I0000 00:00:1719180657.071217 1786170 service.cc:153]   StreamExecutor device (1): NVIDIA TITAN V, Compute Capability 7.0
# 2024-06-23 23:10:57.259241: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-06-23 23:10:58.395526: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8907
#  22/229 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.1442 - mae: 1.6667
# I0000 00:00:1719180678.288855 1786170 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 51s 102ms/step - loss: 6.0242 - mae: 1.5927 - val_loss: 4.5161 - val_mae: 0.2451 - learning_rate: 1.0000e-04
# Epoch 2/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 5.5132 - mae: 1.3024 - val_loss: 4.2333 - val_mae: 0.2110 - learning_rate: 1.0000e-04
# Epoch 3/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 5.0666 - mae: 1.1118 - val_loss: 3.9335 - val_mae: 0.1904 - learning_rate: 1.0000e-04
# Epoch 4/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 4.5869 - mae: 0.9200 - val_loss: 3.5908 - val_mae: 0.1593 - learning_rate: 1.0000e-04
# Epoch 5/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 4.1180 - mae: 0.7694 - val_loss: 3.2368 - val_mae: 0.1510 - learning_rate: 1.0000e-04
# Epoch 6/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 3.6631 - mae: 0.6678 - val_loss: 2.8353 - val_mae: 0.1191 - learning_rate: 1.0000e-04
# Epoch 7/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 3.1926 - mae: 0.5700 - val_loss: 2.4549 - val_mae: 0.1108 - learning_rate: 1.0000e-04
# Epoch 8/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 2.7234 - mae: 0.4677 - val_loss: 2.1012 - val_mae: 0.1101 - learning_rate: 1.0000e-04
# Epoch 9/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 2.3149 - mae: 0.4086 - val_loss: 1.7682 - val_mae: 0.1060 - learning_rate: 1.0000e-04
# Epoch 10/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 1.9280 - mae: 0.3400 - val_loss: 1.4841 - val_mae: 0.1051 - learning_rate: 1.0000e-04
# Epoch 11/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 1.6163 - mae: 0.3002 - val_loss: 1.2406 - val_mae: 0.1016 - learning_rate: 1.0000e-04
# Epoch 12/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 1.3331 - mae: 0.2469 - val_loss: 1.0375 - val_mae: 0.0997 - learning_rate: 1.0000e-04
# Epoch 13/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 1.1134 - mae: 0.2194 - val_loss: 0.8675 - val_mae: 0.0972 - learning_rate: 1.0000e-04
# Epoch 14/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.9179 - mae: 0.1844 - val_loss: 0.7240 - val_mae: 0.0947 - learning_rate: 1.0000e-04
# Epoch 15/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.7570 - mae: 0.1585 - val_loss: 0.6043 - val_mae: 0.0926 - learning_rate: 1.0000e-04
# Epoch 16/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.6258 - mae: 0.1399 - val_loss: 0.5053 - val_mae: 0.0921 - learning_rate: 1.0000e-04
# Epoch 17/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.5227 - mae: 0.1311 - val_loss: 0.4235 - val_mae: 0.0922 - learning_rate: 1.0000e-04
# Epoch 18/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4263 - mae: 0.1126 - val_loss: 0.3555 - val_mae: 0.0910 - learning_rate: 1.0000e-04
# Epoch 19/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3600 - mae: 0.1098 - val_loss: 0.2992 - val_mae: 0.0890 - learning_rate: 1.0000e-04
# Epoch 20/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3034 - mae: 0.1049 - val_loss: 0.2515 - val_mae: 0.0855 - learning_rate: 1.0000e-04
# Epoch 21/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2550 - mae: 0.0983 - val_loss: 0.2165 - val_mae: 0.0861 - learning_rate: 1.0000e-04
# Epoch 22/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2210 - mae: 0.0981 - val_loss: 0.1868 - val_mae: 0.0845 - learning_rate: 1.0000e-04
# Epoch 23/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1878 - mae: 0.0913 - val_loss: 0.1636 - val_mae: 0.0830 - learning_rate: 1.0000e-04
# Epoch 24/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1643 - mae: 0.0881 - val_loss: 0.1453 - val_mae: 0.0813 - learning_rate: 1.0000e-04
# Epoch 25/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1472 - mae: 0.0865 - val_loss: 0.1342 - val_mae: 0.0826 - learning_rate: 1.0000e-04
# Epoch 26/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1312 - mae: 0.0823 - val_loss: 0.1268 - val_mae: 0.0851 - learning_rate: 1.0000e-04
# Epoch 27/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1197 - mae: 0.0799 - val_loss: 0.1123 - val_mae: 0.0777 - learning_rate: 1.0000e-04
# Epoch 28/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1135 - mae: 0.0805 - val_loss: 0.1101 - val_mae: 0.0812 - learning_rate: 1.0000e-04
# Epoch 29/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1084 - mae: 0.0806 - val_loss: 0.1038 - val_mae: 0.0793 - learning_rate: 1.0000e-04
# Epoch 30/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1038 - mae: 0.0802 - val_loss: 0.1017 - val_mae: 0.0805 - learning_rate: 1.0000e-04
# Epoch 31/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0959 - mae: 0.0755 - val_loss: 0.1046 - val_mae: 0.0865 - learning_rate: 1.0000e-04
# Epoch 32/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0934 - mae: 0.0757 - val_loss: 0.0936 - val_mae: 0.0775 - learning_rate: 1.0000e-04
# Epoch 33/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0948 - mae: 0.0792 - val_loss: 0.0942 - val_mae: 0.0798 - learning_rate: 1.0000e-04
# Epoch 34/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0943 - mae: 0.0803 - val_loss: 0.0901 - val_mae: 0.0773 - learning_rate: 1.0000e-04
# Epoch 35/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0906 - mae: 0.0780 - val_loss: 0.0984 - val_mae: 0.0867 - learning_rate: 1.0000e-04
# Epoch 36/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0891 - mae: 0.0775 - val_loss: 0.0890 - val_mae: 0.0781 - learning_rate: 1.0000e-04
# Epoch 37/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0858 - mae: 0.0752 - val_loss: 0.0874 - val_mae: 0.0773 - learning_rate: 1.0000e-04
# Epoch 38/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0866 - mae: 0.0767 - val_loss: 0.0859 - val_mae: 0.0765 - learning_rate: 1.0000e-04
# Epoch 39/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0852 - mae: 0.0758 - val_loss: 0.0864 - val_mae: 0.0775 - learning_rate: 1.0000e-04
# Epoch 40/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0858 - mae: 0.0769 - val_loss: 0.0835 - val_mae: 0.0750 - learning_rate: 1.0000e-04
# Epoch 41/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0823 - mae: 0.0739 - val_loss: 0.0834 - val_mae: 0.0754 - learning_rate: 1.0000e-04
# Epoch 42/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0841 - mae: 0.0762 - val_loss: 0.0819 - val_mae: 0.0743 - learning_rate: 1.0000e-04
# Epoch 43/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0818 - mae: 0.0743 - val_loss: 0.0846 - val_mae: 0.0772 - learning_rate: 1.0000e-04
# Epoch 44/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0826 - mae: 0.0753 - val_loss: 0.0843 - val_mae: 0.0772 - learning_rate: 1.0000e-04
# Epoch 45/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0798 - mae: 0.0728 - val_loss: 0.0947 - val_mae: 0.0879 - learning_rate: 1.0000e-04
# Epoch 46/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0804 - mae: 0.0736 - val_loss: 0.0913 - val_mae: 0.0847 - learning_rate: 1.0000e-04
# Epoch 47/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0829 - mae: 0.0762 - val_loss: 0.0921 - val_mae: 0.0855 - learning_rate: 1.0000e-04
# Epoch 48/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0821 - mae: 0.0755 - val_loss: 0.0793 - val_mae: 0.0730 - learning_rate: 5.0000e-05
# Epoch 49/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0775 - mae: 0.0713 - val_loss: 0.0811 - val_mae: 0.0750 - learning_rate: 5.0000e-05
# Epoch 50/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0785 - mae: 0.0725 - val_loss: 0.0835 - val_mae: 0.0776 - learning_rate: 5.0000e-05
# Epoch 51/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0793 - mae: 0.0735 - val_loss: 0.0753 - val_mae: 0.0696 - learning_rate: 5.0000e-05
# Epoch 52/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0770 - mae: 0.0713 - val_loss: 0.0790 - val_mae: 0.0733 - learning_rate: 5.0000e-05
# Epoch 53/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0776 - mae: 0.0719 - val_loss: 0.0900 - val_mae: 0.0843 - learning_rate: 5.0000e-05
# Epoch 54/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0780 - mae: 0.0723 - val_loss: 0.0787 - val_mae: 0.0730 - learning_rate: 5.0000e-05
# Epoch 55/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0798 - mae: 0.0741 - val_loss: 0.0793 - val_mae: 0.0736 - learning_rate: 5.0000e-05
# Epoch 56/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0778 - mae: 0.0721 - val_loss: 0.0814 - val_mae: 0.0756 - learning_rate: 5.0000e-05
# Epoch 57/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0750 - mae: 0.0692 - val_loss: 0.0750 - val_mae: 0.0693 - learning_rate: 2.5000e-05
# Epoch 58/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0766 - mae: 0.0710 - val_loss: 0.0748 - val_mae: 0.0692 - learning_rate: 2.5000e-05
# Epoch 59/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0772 - mae: 0.0716 - val_loss: 0.0732 - val_mae: 0.0676 - learning_rate: 2.5000e-05
# Epoch 60/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0773 - mae: 0.0718 - val_loss: 0.0745 - val_mae: 0.0690 - learning_rate: 2.5000e-05
# Epoch 61/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0751 - mae: 0.0696 - val_loss: 0.0748 - val_mae: 0.0693 - learning_rate: 2.5000e-05
# Epoch 62/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0779 - mae: 0.0723 - val_loss: 0.0720 - val_mae: 0.0664 - learning_rate: 2.5000e-05
# Epoch 63/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0760 - mae: 0.0705 - val_loss: 0.0746 - val_mae: 0.0691 - learning_rate: 2.5000e-05
# Epoch 64/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0755 - mae: 0.0700 - val_loss: 0.0727 - val_mae: 0.0672 - learning_rate: 2.5000e-05
# Epoch 65/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0763 - mae: 0.0707 - val_loss: 0.0741 - val_mae: 0.0686 - learning_rate: 2.5000e-05
# Epoch 66/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0765 - mae: 0.0710 - val_loss: 0.0713 - val_mae: 0.0658 - learning_rate: 2.5000e-05
# Epoch 67/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0749 - mae: 0.0694 - val_loss: 0.0734 - val_mae: 0.0679 - learning_rate: 2.5000e-05
# Epoch 68/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0756 - mae: 0.0701 - val_loss: 0.0708 - val_mae: 0.0653 - learning_rate: 2.5000e-05
# Epoch 69/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0755 - mae: 0.0700 - val_loss: 0.0749 - val_mae: 0.0693 - learning_rate: 2.5000e-05
# Epoch 70/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0761 - mae: 0.0706 - val_loss: 0.0805 - val_mae: 0.0749 - learning_rate: 2.5000e-05
# Epoch 71/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0753 - mae: 0.0697 - val_loss: 0.0711 - val_mae: 0.0656 - learning_rate: 2.5000e-05
# Epoch 72/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0734 - mae: 0.0678 - val_loss: 0.0691 - val_mae: 0.0635 - learning_rate: 2.5000e-05
# Epoch 73/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0741 - mae: 0.0685 - val_loss: 0.0698 - val_mae: 0.0642 - learning_rate: 2.5000e-05
# Epoch 74/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0741 - mae: 0.0685 - val_loss: 0.0745 - val_mae: 0.0690 - learning_rate: 2.5000e-05
# Epoch 75/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0740 - mae: 0.0684 - val_loss: 0.0722 - val_mae: 0.0666 - learning_rate: 2.5000e-05
# Epoch 76/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0755 - mae: 0.0699 - val_loss: 0.0709 - val_mae: 0.0653 - learning_rate: 2.5000e-05
# Epoch 77/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0732 - mae: 0.0675 - val_loss: 0.0702 - val_mae: 0.0646 - learning_rate: 2.5000e-05
# Epoch 78/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0730 - mae: 0.0674 - val_loss: 0.0724 - val_mae: 0.0667 - learning_rate: 1.2500e-05
# Epoch 79/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0704 - mae: 0.0648 - val_loss: 0.0678 - val_mae: 0.0622 - learning_rate: 1.2500e-05
# Epoch 80/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0724 - mae: 0.0668 - val_loss: 0.0682 - val_mae: 0.0625 - learning_rate: 1.2500e-05
# Epoch 81/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0715 - mae: 0.0659 - val_loss: 0.0708 - val_mae: 0.0652 - learning_rate: 1.2500e-05
# Epoch 82/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0718 - mae: 0.0662 - val_loss: 0.0672 - val_mae: 0.0617 - learning_rate: 1.2500e-05
# Epoch 83/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0702 - mae: 0.0646 - val_loss: 0.0697 - val_mae: 0.0641 - learning_rate: 1.2500e-05
# Epoch 84/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0721 - mae: 0.0665 - val_loss: 0.0666 - val_mae: 0.0610 - learning_rate: 1.2500e-05
# Epoch 85/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0705 - mae: 0.0649 - val_loss: 0.0666 - val_mae: 0.0610 - learning_rate: 1.2500e-05
# Epoch 86/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0726 - mae: 0.0670 - val_loss: 0.0674 - val_mae: 0.0618 - learning_rate: 1.2500e-05
# Epoch 87/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0742 - mae: 0.0686 - val_loss: 0.0692 - val_mae: 0.0637 - learning_rate: 1.2500e-05
# Epoch 88/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0691 - mae: 0.0635 - val_loss: 0.0705 - val_mae: 0.0650 - learning_rate: 1.2500e-05
# Epoch 89/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0725 - mae: 0.0669 - val_loss: 0.0659 - val_mae: 0.0604 - learning_rate: 1.2500e-05
# Epoch 90/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0711 - mae: 0.0656 - val_loss: 0.0661 - val_mae: 0.0606 - learning_rate: 1.2500e-05
# Epoch 91/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0733 - mae: 0.0678 - val_loss: 0.0658 - val_mae: 0.0602 - learning_rate: 1.2500e-05
# Epoch 92/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0714 - mae: 0.0658 - val_loss: 0.0649 - val_mae: 0.0594 - learning_rate: 1.2500e-05
# Epoch 93/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0722 - mae: 0.0667 - val_loss: 0.0659 - val_mae: 0.0604 - learning_rate: 1.2500e-05
# Epoch 94/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0708 - mae: 0.0653 - val_loss: 0.0782 - val_mae: 0.0727 - learning_rate: 1.2500e-05
# Epoch 95/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0707 - mae: 0.0652 - val_loss: 0.0644 - val_mae: 0.0589 - learning_rate: 1.2500e-05
# Epoch 96/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0699 - mae: 0.0644 - val_loss: 0.0692 - val_mae: 0.0637 - learning_rate: 1.2500e-05
# Epoch 97/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0719 - mae: 0.0664 - val_loss: 0.0699 - val_mae: 0.0644 - learning_rate: 1.2500e-05
# Epoch 98/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0699 - mae: 0.0643 - val_loss: 0.0676 - val_mae: 0.0621 - learning_rate: 1.2500e-05
# Epoch 99/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0682 - mae: 0.0627 - val_loss: 0.0673 - val_mae: 0.0617 - learning_rate: 1.2500e-05
# Epoch 100/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0709 - mae: 0.0653 - val_loss: 0.0654 - val_mae: 0.0599 - learning_rate: 1.2500e-05
# Epoch 101/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0719 - mae: 0.0664 - val_loss: 0.0753 - val_mae: 0.0697 - learning_rate: 6.2500e-06
# Epoch 102/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0703 - mae: 0.0647 - val_loss: 0.0729 - val_mae: 0.0674 - learning_rate: 6.2500e-06
# Epoch 103/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0718 - mae: 0.0662 - val_loss: 0.0640 - val_mae: 0.0585 - learning_rate: 6.2500e-06
# Epoch 104/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0708 - mae: 0.0653 - val_loss: 0.0713 - val_mae: 0.0658 - learning_rate: 6.2500e-06
# Epoch 105/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0705 - mae: 0.0650 - val_loss: 0.0645 - val_mae: 0.0590 - learning_rate: 6.2500e-06
# Epoch 106/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0704 - mae: 0.0648 - val_loss: 0.0669 - val_mae: 0.0614 - learning_rate: 6.2500e-06
# Epoch 107/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0729 - mae: 0.0674 - val_loss: 0.0636 - val_mae: 0.0581 - learning_rate: 6.2500e-06
# Epoch 108/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0699 - mae: 0.0644 - val_loss: 0.0679 - val_mae: 0.0624 - learning_rate: 6.2500e-06
# Epoch 109/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0691 - mae: 0.0636 - val_loss: 0.0676 - val_mae: 0.0621 - learning_rate: 6.2500e-06
# Epoch 110/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0716 - mae: 0.0661 - val_loss: 0.0675 - val_mae: 0.0619 - learning_rate: 6.2500e-06
# Epoch 111/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0697 - mae: 0.0642 - val_loss: 0.0709 - val_mae: 0.0655 - learning_rate: 6.2500e-06
# Epoch 112/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0700 - mae: 0.0645 - val_loss: 0.0660 - val_mae: 0.0605 - learning_rate: 6.2500e-06
# Epoch 113/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0694 - mae: 0.0639 - val_loss: 0.0640 - val_mae: 0.0585 - learning_rate: 3.1250e-06
# Epoch 114/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0681 - mae: 0.0626 - val_loss: 0.0668 - val_mae: 0.0613 - learning_rate: 3.1250e-06
# Epoch 115/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0708 - mae: 0.0653 - val_loss: 0.0634 - val_mae: 0.0579 - learning_rate: 3.1250e-06
# Epoch 116/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0719 - mae: 0.0664 - val_loss: 0.0629 - val_mae: 0.0574 - learning_rate: 3.1250e-06
# Epoch 117/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0698 - mae: 0.0643 - val_loss: 0.0629 - val_mae: 0.0574 - learning_rate: 3.1250e-06
# Epoch 118/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0707 - mae: 0.0652 - val_loss: 0.0668 - val_mae: 0.0613 - learning_rate: 3.1250e-06
# Epoch 119/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0704 - mae: 0.0649 - val_loss: 0.0637 - val_mae: 0.0582 - learning_rate: 3.1250e-06
# Epoch 120/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0693 - mae: 0.0639 - val_loss: 0.0645 - val_mae: 0.0590 - learning_rate: 3.1250e-06
# Epoch 121/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0692 - mae: 0.0637 - val_loss: 0.0628 - val_mae: 0.0574 - learning_rate: 3.1250e-06
# Epoch 122/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0684 - mae: 0.0629 - val_loss: 0.0640 - val_mae: 0.0585 - learning_rate: 1.5625e-06
# Epoch 123/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0684 - mae: 0.0629 - val_loss: 0.0665 - val_mae: 0.0610 - learning_rate: 1.5625e-06
# Epoch 124/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0706 - mae: 0.0651 - val_loss: 0.0647 - val_mae: 0.0592 - learning_rate: 1.5625e-06
# Epoch 125/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0708 - mae: 0.0653 - val_loss: 0.0660 - val_mae: 0.0605 - learning_rate: 1.5625e-06
# Epoch 126/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0670 - mae: 0.0616 - val_loss: 0.0634 - val_mae: 0.0579 - learning_rate: 1.5625e-06
# Epoch 127/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0679 - mae: 0.0624 - val_loss: 0.0640 - val_mae: 0.0585 - learning_rate: 1.0000e-06
# Epoch 128/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0712 - mae: 0.0657 - val_loss: 0.0630 - val_mae: 0.0576 - learning_rate: 1.0000e-06
# Epoch 129/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0703 - mae: 0.0648 - val_loss: 0.0659 - val_mae: 0.0604 - learning_rate: 1.0000e-06
# Epoch 130/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0685 - mae: 0.0631 - val_loss: 0.0646 - val_mae: 0.0591 - learning_rate: 1.0000e-06
# Epoch 131/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0676 - mae: 0.0621 - val_loss: 0.0628 - val_mae: 0.0573 - learning_rate: 1.0000e-06
# Epoch 132/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0704 - mae: 0.0650 - val_loss: 0.0650 - val_mae: 0.0595 - learning_rate: 1.0000e-06
# Epoch 133/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0667 - mae: 0.0613 - val_loss: 0.0640 - val_mae: 0.0585 - learning_rate: 1.0000e-06
# Epoch 134/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0708 - mae: 0.0653 - val_loss: 0.0643 - val_mae: 0.0589 - learning_rate: 1.0000e-06
# Epoch 135/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0677 - mae: 0.0623 - val_loss: 0.0635 - val_mae: 0.0580 - learning_rate: 1.0000e-06
# Epoch 136/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0701 - mae: 0.0647 - val_loss: 0.0648 - val_mae: 0.0593 - learning_rate: 1.0000e-06
# Epoch 137/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0705 - mae: 0.0650 - val_loss: 0.0648 - val_mae: 0.0593 - learning_rate: 1.0000e-06
# Epoch 138/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0676 - mae: 0.0622 - val_loss: 0.0640 - val_mae: 0.0585 - learning_rate: 1.0000e-06
# Epoch 139/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0699 - mae: 0.0644 - val_loss: 0.0634 - val_mae: 0.0579 - learning_rate: 1.0000e-06
# Epoch 140/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0683 - mae: 0.0628 - val_loss: 0.0650 - val_mae: 0.0596 - learning_rate: 1.0000e-06
# Epoch 141/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0695 - mae: 0.0640 - val_loss: 0.0639 - val_mae: 0.0584 - learning_rate: 1.0000e-06
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0617 - mae: 0.0562
# Validation MAE: 0.057291146367788315
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0591 - mae: 0.0536
# Test MAE: 0.05759014934301376

# %%
from tensorflow.keras.models import load_model

# Load the saved model
model = load_model('aot_model.keras')

# Load the new dataset
new_df = pd.read_csv("datasets/test.csv")

# Preprocess numerical data
new_numerical_features = new_df[['elevation', 'ozone', 'NO2', 'azimuth', 'zenith', 'incidence_azimuth', 'incidence_zenith']]
new_numerical_features = scaler.transform(new_numerical_features)

# Load and preprocess new image data
new_image_data = np.array([load_and_preprocess_image(os.path.join('./test/', filename)) for filename in new_df['file_name_l1']])

# Predict values for the new data
predictions = model.predict([new_image_data, new_numerical_features])

# Save the predictions to a CSV file
results = pd.DataFrame({
    'id': new_df['id'],
    'value_550': predictions.flatten()
})
results.to_csv('predictions.csv', index=False)

print(results.head())
# Out:
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step
#    id  value_550
# 0   3   0.112031
# 1  25   0.117409
# 2  26   0.072785
# 3  27   0.167566
# 4  29   0.077490
