# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
import numpy as np
import os
import tifffile as tiff
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Input, Concatenate, BatchNormalization, Dropout, GlobalAveragePooling2D, Add, LeakyReLU
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, LearningRateScheduler
from tensorflow.keras.initializers import HeNormal, HeUniform
import tensorflow as tf
from tensorflow.keras.optimizers import Adam, RMSprop, Nadam

# tf.keras.backend.clear_session()

print("split started")
# Load the dataset
df = pd.read_csv("datasets/train.csv")

print(f'Number of features: {df.shape[1]}')
print(f'Number of instances: {df.shape[0]}')
df.head()

# Preprocess numerical data
numerical_features = df[['elevation', 'ozone', 'NO2', 'azimuth', 'zenith', 'incidence_azimuth', 'incidence_zenith']]

# Numerical data scaling
scaler = StandardScaler()
numerical_features = scaler.fit_transform(numerical_features)

# Function to load and preprocess image data
def load_and_preprocess_image(filepath):
    img = tiff.imread(filepath)
    img_array = np.array(img)
    img_array = img_array / 65535.0   # Normalize pixel values
    return img_array

# Load image data
image_data = np.array([load_and_preprocess_image(os.path.join('./train/', filename)) for filename in df['file_name_l1']])

# Target variable
target = df['value_550'].values

# Split data into training, validation, and testing sets without stratification
from sklearn.model_selection import train_test_split

X_train_num, X_temp_num, X_train_img, X_temp_img, y_train, y_temp = train_test_split(numerical_features, image_data, target, test_size=0.3, random_state=42)
X_val_num, X_test_num, X_val_img, X_test_img, y_val, y_test = train_test_split(X_temp_num, X_temp_img, y_temp, test_size=0.5, random_state=42)

print("split done")

# Define the CNN and dense model
class AOTModel:
    def __init__(self, image_shape=(19, 19, 13), num_numerical_features=7):
        # Image processing Neural Network
        self.image_input = Input(shape=image_shape)
        initializer = HeUniform()
        
        image_processing_network = Conv2D(32, (3, 3), kernel_regularizer=l2(0.01), kernel_initializer=initializer)(self.image_input)
        image_processing_network = BatchNormalization()(image_processing_network)
        image_processing_network = LeakyReLU()(image_processing_network)
        image_processing_network = MaxPooling2D((2, 2))(image_processing_network)
        image_processing_network = Dropout(0.25)(image_processing_network)

        image_processing_network = Conv2D(64, (3, 3), kernel_regularizer=l2(0.01), kernel_initializer=initializer)(image_processing_network)
        image_processing_network = BatchNormalization()(image_processing_network)
        image_processing_network = LeakyReLU()(image_processing_network)
        image_processing_network = MaxPooling2D((2, 2))(image_processing_network)
        image_processing_network = Dropout(0.25)(image_processing_network)

        image_processing_network = Conv2D(128, (3, 3), kernel_regularizer=l2(0.01), kernel_initializer=initializer)(image_processing_network)
        image_processing_network = BatchNormalization()(image_processing_network)
        image_processing_network = LeakyReLU()(image_processing_network)
        image_processing_network = GlobalAveragePooling2D()(image_processing_network)
        image_processing_network = Dropout(0.5)(image_processing_network)

        # Residual connection
        residual = Conv2D(128, (1, 1), kernel_regularizer=l2(0.01), kernel_initializer=initializer)(self.image_input)
        residual = BatchNormalization()(residual)
        residual = GlobalAveragePooling2D()(residual)
        image_processing_network = Add()([image_processing_network, residual])

        # Numerical processing Neural Network
        self.numerical_input = Input(shape=(num_numerical_features,))
        numerical_processing_network = Dense(64, activation='relu', kernel_initializer=initializer)(self.numerical_input)
        numerical_processing_network = BatchNormalization()(numerical_processing_network)
        numerical_processing_network = Dropout(0.5)(numerical_processing_network)
        
        numerical_processing_network = Dense(128, activation='relu', kernel_initializer=initializer)(numerical_processing_network)
        numerical_processing_network = BatchNormalization()(numerical_processing_network)
        numerical_processing_network = Dropout(0.5)(numerical_processing_network)

        numerical_processing_network = Dense(64, activation='relu', kernel_initializer=initializer)(numerical_processing_network)
        numerical_processing_network = BatchNormalization()(numerical_processing_network)
        numerical_processing_network = Dropout(0.5)(numerical_processing_network)
        
        # Concatenation of both networks
        aot_network = Concatenate()([image_processing_network, numerical_processing_network])
        aot_network = Dense(64, activation='relu', kernel_initializer=initializer)(aot_network)
        aot_network = Dropout(0.5)(aot_network)
        aot_network = Dense(1, kernel_initializer=initializer)(aot_network)

        self.aot_network_arquitecture = aot_network
        del image_processing_network, numerical_processing_network, aot_network

    def model(self, learning_rate=0.001, optimizer_choice='adam'):
        model = Model(inputs=[self.image_input, self.numerical_input], outputs=self.aot_network_arquitecture)
        
        if optimizer_choice == 'adam':
            optimizer = Adam(learning_rate=learning_rate, clipnorm=1.0)
        elif optimizer_choice == 'rmsprop':
            optimizer = RMSprop(learning_rate=learning_rate, clipnorm=1.0)
        elif optimizer_choice == 'nadam':
            optimizer = Nadam(learning_rate=learning_rate, clipnorm=1.0)
        else:
            optimizer = Adam(learning_rate=learning_rate, clipnorm=1.0)
        
        model.compile(optimizer=optimizer, loss='mean_absolute_error', metrics=['mae'])
        return model

# Instantiate the model with a chosen optimizer
model = AOTModel().model(learning_rate=0.0001, optimizer_choice='adam')

# Define callbacks
def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * np.exp(-0.1)

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
# lr_scheduler = LearningRateScheduler(scheduler)

print("starting training")
# Train the model
history = model.fit(
    [X_train_img, X_train_num], y_train,
    validation_data=([X_val_img, X_val_num], y_val),
    epochs=200,
    batch_size=32,
    callbacks=[early_stopping, reduce_lr],
    verbose=1
)

model.save('aot_model.keras')

# Evaluate the model
val_loss, val_mae = model.evaluate([X_val_img, X_val_num], y_val)
print(f'Validation MAE: {val_mae}')

# Evaluate on test set
test_loss, test_mae = model.evaluate([X_test_img, X_test_num], y_test)
print(f'Test MAE: {test_mae}')
# Out:
# split started
# Number of features: 10
# Number of instances: 10438
# split done
# starting training
# Epoch 1/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 51s 105ms/step - loss: 8.9479 - mae: 1.8060 - val_loss: 7.1918 - val_mae: 0.3253 - learning_rate: 1.0000e-04
# Epoch 2/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 8.1199 - mae: 1.3487 - val_loss: 6.7462 - val_mae: 0.2707 - learning_rate: 1.0000e-04
# Epoch 3/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 7.4572 - mae: 1.0837 - val_loss: 6.3252 - val_mae: 0.2642 - learning_rate: 1.0000e-04
# Epoch 4/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 6.8404 - mae: 0.8881 - val_loss: 5.8611 - val_mae: 0.2391 - learning_rate: 1.0000e-04
# Epoch 5/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 6.2532 - mae: 0.7455 - val_loss: 5.3415 - val_mae: 0.1865 - learning_rate: 1.0000e-04
# Epoch 6/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 5.6564 - mae: 0.6215 - val_loss: 4.8110 - val_mae: 0.1454 - learning_rate: 1.0000e-04
# Epoch 7/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 5.0519 - mae: 0.5092 - val_loss: 4.2925 - val_mae: 0.1200 - learning_rate: 1.0000e-04
# Epoch 8/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 4.4779 - mae: 0.4248 - val_loss: 3.8053 - val_mae: 0.1075 - learning_rate: 1.0000e-04
# Epoch 9/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 3.9308 - mae: 0.3482 - val_loss: 3.3454 - val_mae: 0.1019 - learning_rate: 1.0000e-04
# Epoch 10/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 3.4223 - mae: 0.2856 - val_loss: 2.9208 - val_mae: 0.0945 - learning_rate: 1.0000e-04
# Epoch 11/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 2.9674 - mae: 0.2358 - val_loss: 2.5545 - val_mae: 0.0945 - learning_rate: 1.0000e-04
# Epoch 12/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 2.5664 - mae: 0.1890 - val_loss: 2.2336 - val_mae: 0.0927 - learning_rate: 1.0000e-04
# Epoch 13/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 2.2261 - mae: 0.1577 - val_loss: 1.9529 - val_mae: 0.0921 - learning_rate: 1.0000e-04
# Epoch 14/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 1.9297 - mae: 0.1328 - val_loss: 1.7056 - val_mae: 0.0912 - learning_rate: 1.0000e-04
# Epoch 15/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 1.6831 - mae: 0.1247 - val_loss: 1.4889 - val_mae: 0.0909 - learning_rate: 1.0000e-04
# Epoch 16/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 1.4616 - mae: 0.1127 - val_loss: 1.2986 - val_mae: 0.0902 - learning_rate: 1.0000e-04
# Epoch 17/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 1.2721 - mae: 0.1068 - val_loss: 1.1318 - val_mae: 0.0894 - learning_rate: 1.0000e-04
# Epoch 18/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 1.1066 - mae: 0.1017 - val_loss: 0.9857 - val_mae: 0.0880 - learning_rate: 1.0000e-04
# Epoch 19/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.9611 - mae: 0.0960 - val_loss: 0.8575 - val_mae: 0.0856 - learning_rate: 1.0000e-04
# Epoch 20/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.8369 - mae: 0.0933 - val_loss: 0.7483 - val_mae: 0.0844 - learning_rate: 1.0000e-04
# Epoch 21/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.7311 - mae: 0.0913 - val_loss: 0.6541 - val_mae: 0.0835 - learning_rate: 1.0000e-04
# Epoch 22/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.6343 - mae: 0.0849 - val_loss: 0.5742 - val_mae: 0.0851 - learning_rate: 1.0000e-04
# Epoch 23/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.5569 - mae: 0.0861 - val_loss: 0.5004 - val_mae: 0.0814 - learning_rate: 1.0000e-04
# Epoch 24/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.4890 - mae: 0.0857 - val_loss: 0.4404 - val_mae: 0.0813 - learning_rate: 1.0000e-04
# Epoch 25/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.4272 - mae: 0.0818 - val_loss: 0.3907 - val_mae: 0.0840 - learning_rate: 1.0000e-04
# Epoch 26/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.3743 - mae: 0.0792 - val_loss: 0.3418 - val_mae: 0.0796 - learning_rate: 1.0000e-04
# Epoch 27/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.3333 - mae: 0.0812 - val_loss: 0.3032 - val_mae: 0.0798 - learning_rate: 1.0000e-04
# Epoch 28/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2932 - mae: 0.0785 - val_loss: 0.2735 - val_mae: 0.0833 - learning_rate: 1.0000e-04
# Epoch 29/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2624 - mae: 0.0797 - val_loss: 0.2394 - val_mae: 0.0780 - learning_rate: 1.0000e-04
# Epoch 30/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.2348 - mae: 0.0798 - val_loss: 0.2146 - val_mae: 0.0777 - learning_rate: 1.0000e-04
# Epoch 31/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2087 - mae: 0.0774 - val_loss: 0.1978 - val_mae: 0.0823 - learning_rate: 1.0000e-04
# Epoch 32/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1867 - mae: 0.0760 - val_loss: 0.1768 - val_mae: 0.0796 - learning_rate: 1.0000e-04
# Epoch 33/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1710 - mae: 0.0778 - val_loss: 0.1601 - val_mae: 0.0787 - learning_rate: 1.0000e-04
# Epoch 34/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1565 - mae: 0.0785 - val_loss: 0.1504 - val_mae: 0.0824 - learning_rate: 1.0000e-04
# Epoch 35/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1423 - mae: 0.0770 - val_loss: 0.1376 - val_mae: 0.0807 - learning_rate: 1.0000e-04
# Epoch 36/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1335 - mae: 0.0791 - val_loss: 0.1228 - val_mae: 0.0756 - learning_rate: 1.0000e-04
# Epoch 37/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1205 - mae: 0.0754 - val_loss: 0.1217 - val_mae: 0.0825 - learning_rate: 1.0000e-04
# Epoch 38/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1117 - mae: 0.0742 - val_loss: 0.1156 - val_mae: 0.0831 - learning_rate: 1.0000e-04
# Epoch 39/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1064 - mae: 0.0754 - val_loss: 0.0998 - val_mae: 0.0728 - learning_rate: 1.0000e-04
# Epoch 40/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1015 - mae: 0.0756 - val_loss: 0.1063 - val_mae: 0.0837 - learning_rate: 1.0000e-04
# Epoch 41/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0983 - mae: 0.0767 - val_loss: 0.1090 - val_mae: 0.0901 - learning_rate: 1.0000e-04
# Epoch 42/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0926 - mae: 0.0745 - val_loss: 0.0946 - val_mae: 0.0787 - learning_rate: 1.0000e-04
# Epoch 43/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0925 - mae: 0.0772 - val_loss: 0.0917 - val_mae: 0.0780 - learning_rate: 1.0000e-04
# Epoch 44/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0887 - mae: 0.0755 - val_loss: 0.0852 - val_mae: 0.0735 - learning_rate: 1.0000e-04
# Epoch 45/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0887 - mae: 0.0772 - val_loss: 0.0938 - val_mae: 0.0833 - learning_rate: 1.0000e-04
# Epoch 46/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0843 - mae: 0.0742 - val_loss: 0.1020 - val_mae: 0.0927 - learning_rate: 1.0000e-04
# Epoch 47/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0826 - mae: 0.0735 - val_loss: 0.0926 - val_mae: 0.0841 - learning_rate: 1.0000e-04
# Epoch 48/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0828 - mae: 0.0745 - val_loss: 0.0918 - val_mae: 0.0839 - learning_rate: 1.0000e-04
# Epoch 49/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0839 - mae: 0.0761 - val_loss: 0.0806 - val_mae: 0.0731 - learning_rate: 1.0000e-04
# Epoch 50/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0806 - mae: 0.0733 - val_loss: 0.0857 - val_mae: 0.0786 - learning_rate: 1.0000e-04
# Epoch 51/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0829 - mae: 0.0758 - val_loss: 0.0869 - val_mae: 0.0801 - learning_rate: 1.0000e-04
# Epoch 52/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0804 - mae: 0.0736 - val_loss: 0.0840 - val_mae: 0.0773 - learning_rate: 1.0000e-04
# Epoch 53/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0773 - mae: 0.0705 - val_loss: 0.0871 - val_mae: 0.0804 - learning_rate: 1.0000e-04
# Epoch 54/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0824 - mae: 0.0757 - val_loss: 0.0850 - val_mae: 0.0785 - learning_rate: 1.0000e-04
# Epoch 55/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0800 - mae: 0.0736 - val_loss: 0.0756 - val_mae: 0.0694 - learning_rate: 5.0000e-05
# Epoch 56/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0788 - mae: 0.0727 - val_loss: 0.0862 - val_mae: 0.0803 - learning_rate: 5.0000e-05
# Epoch 57/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0748 - mae: 0.0688 - val_loss: 0.0786 - val_mae: 0.0727 - learning_rate: 5.0000e-05
# Epoch 58/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0778 - mae: 0.0718 - val_loss: 0.0793 - val_mae: 0.0734 - learning_rate: 5.0000e-05
# Epoch 59/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0760 - mae: 0.0701 - val_loss: 0.0752 - val_mae: 0.0694 - learning_rate: 5.0000e-05
# Epoch 60/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0791 - mae: 0.0733 - val_loss: 0.0735 - val_mae: 0.0678 - learning_rate: 5.0000e-05
# Epoch 61/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0772 - mae: 0.0714 - val_loss: 0.0795 - val_mae: 0.0738 - learning_rate: 5.0000e-05
# Epoch 62/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0772 - mae: 0.0714 - val_loss: 0.0719 - val_mae: 0.0661 - learning_rate: 5.0000e-05
# Epoch 63/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0784 - mae: 0.0726 - val_loss: 0.0756 - val_mae: 0.0698 - learning_rate: 5.0000e-05
# Epoch 64/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0782 - mae: 0.0724 - val_loss: 0.0837 - val_mae: 0.0779 - learning_rate: 5.0000e-05
# Epoch 65/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0732 - mae: 0.0674 - val_loss: 0.0832 - val_mae: 0.0773 - learning_rate: 5.0000e-05
# Epoch 66/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0765 - mae: 0.0706 - val_loss: 0.0732 - val_mae: 0.0675 - learning_rate: 5.0000e-05
# Epoch 67/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0746 - mae: 0.0688 - val_loss: 0.0766 - val_mae: 0.0708 - learning_rate: 5.0000e-05
# Epoch 68/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0715 - mae: 0.0658 - val_loss: 0.0774 - val_mae: 0.0717 - learning_rate: 2.5000e-05
# Epoch 69/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0764 - mae: 0.0707 - val_loss: 0.0714 - val_mae: 0.0658 - learning_rate: 2.5000e-05
# Epoch 70/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0740 - mae: 0.0684 - val_loss: 0.0792 - val_mae: 0.0735 - learning_rate: 2.5000e-05
# Epoch 71/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0756 - mae: 0.0700 - val_loss: 0.0750 - val_mae: 0.0694 - learning_rate: 2.5000e-05
# Epoch 72/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0766 - mae: 0.0709 - val_loss: 0.0713 - val_mae: 0.0657 - learning_rate: 2.5000e-05
# Epoch 73/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0754 - mae: 0.0698 - val_loss: 0.0725 - val_mae: 0.0669 - learning_rate: 2.5000e-05
# Epoch 74/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0746 - mae: 0.0690 - val_loss: 0.0694 - val_mae: 0.0638 - learning_rate: 2.5000e-05
# Epoch 75/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0757 - mae: 0.0701 - val_loss: 0.0729 - val_mae: 0.0673 - learning_rate: 2.5000e-05
# Epoch 76/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0729 - mae: 0.0673 - val_loss: 0.0755 - val_mae: 0.0699 - learning_rate: 2.5000e-05
# Epoch 77/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0737 - mae: 0.0681 - val_loss: 0.0713 - val_mae: 0.0657 - learning_rate: 2.5000e-05
# Epoch 78/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0728 - mae: 0.0672 - val_loss: 0.0781 - val_mae: 0.0725 - learning_rate: 2.5000e-05
# Epoch 79/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0732 - mae: 0.0675 - val_loss: 0.0717 - val_mae: 0.0661 - learning_rate: 2.5000e-05
# Epoch 80/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0751 - mae: 0.0695 - val_loss: 0.0688 - val_mae: 0.0632 - learning_rate: 1.2500e-05
# Epoch 81/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0737 - mae: 0.0681 - val_loss: 0.0699 - val_mae: 0.0644 - learning_rate: 1.2500e-05
# Epoch 82/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0739 - mae: 0.0684 - val_loss: 0.0720 - val_mae: 0.0664 - learning_rate: 1.2500e-05
# Epoch 83/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0724 - mae: 0.0668 - val_loss: 0.0676 - val_mae: 0.0620 - learning_rate: 1.2500e-05
# Epoch 84/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0741 - mae: 0.0685 - val_loss: 0.0690 - val_mae: 0.0634 - learning_rate: 1.2500e-05
# Epoch 85/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0725 - mae: 0.0670 - val_loss: 0.0678 - val_mae: 0.0623 - learning_rate: 1.2500e-05
# Epoch 86/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0724 - mae: 0.0669 - val_loss: 0.0676 - val_mae: 0.0621 - learning_rate: 1.2500e-05
# Epoch 87/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0720 - mae: 0.0665 - val_loss: 0.0716 - val_mae: 0.0661 - learning_rate: 1.2500e-05
# Epoch 88/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0731 - mae: 0.0676 - val_loss: 0.0731 - val_mae: 0.0676 - learning_rate: 1.2500e-05
# Epoch 89/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0724 - mae: 0.0670 - val_loss: 0.0704 - val_mae: 0.0650 - learning_rate: 6.2500e-06
# Epoch 90/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0702 - mae: 0.0647 - val_loss: 0.0711 - val_mae: 0.0656 - learning_rate: 6.2500e-06
# Epoch 91/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0708 - mae: 0.0654 - val_loss: 0.0659 - val_mae: 0.0604 - learning_rate: 6.2500e-06
# Epoch 92/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0716 - mae: 0.0661 - val_loss: 0.0676 - val_mae: 0.0622 - learning_rate: 6.2500e-06
# Epoch 93/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0747 - mae: 0.0693 - val_loss: 0.0667 - val_mae: 0.0613 - learning_rate: 6.2500e-06
# Epoch 94/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0728 - mae: 0.0674 - val_loss: 0.0653 - val_mae: 0.0599 - learning_rate: 6.2500e-06
# Epoch 95/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0694 - mae: 0.0639 - val_loss: 0.0675 - val_mae: 0.0621 - learning_rate: 6.2500e-06
# Epoch 96/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0705 - mae: 0.0651 - val_loss: 0.0665 - val_mae: 0.0611 - learning_rate: 6.2500e-06
# Epoch 97/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0706 - mae: 0.0652 - val_loss: 0.0650 - val_mae: 0.0596 - learning_rate: 6.2500e-06
# Epoch 98/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0722 - mae: 0.0668 - val_loss: 0.0646 - val_mae: 0.0592 - learning_rate: 6.2500e-06
# Epoch 99/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0719 - mae: 0.0664 - val_loss: 0.0702 - val_mae: 0.0648 - learning_rate: 6.2500e-06
# Epoch 100/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0716 - mae: 0.0662 - val_loss: 0.0702 - val_mae: 0.0647 - learning_rate: 6.2500e-06
# Epoch 101/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0711 - mae: 0.0657 - val_loss: 0.0656 - val_mae: 0.0602 - learning_rate: 6.2500e-06
# Epoch 102/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0706 - mae: 0.0652 - val_loss: 0.0650 - val_mae: 0.0596 - learning_rate: 6.2500e-06
# Epoch 103/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0717 - mae: 0.0663 - val_loss: 0.0665 - val_mae: 0.0611 - learning_rate: 6.2500e-06
# Epoch 104/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0723 - mae: 0.0669 - val_loss: 0.0650 - val_mae: 0.0596 - learning_rate: 3.1250e-06
# Epoch 105/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0753 - mae: 0.0699 - val_loss: 0.0665 - val_mae: 0.0611 - learning_rate: 3.1250e-06
# Epoch 106/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0724 - mae: 0.0671 - val_loss: 0.0670 - val_mae: 0.0616 - learning_rate: 3.1250e-06
# Epoch 107/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0713 - mae: 0.0659 - val_loss: 0.0681 - val_mae: 0.0627 - learning_rate: 3.1250e-06
# Epoch 108/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0702 - mae: 0.0648 - val_loss: 0.0672 - val_mae: 0.0618 - learning_rate: 3.1250e-06
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0648 - mae: 0.0594
# Validation MAE: 0.05921853333711624
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0616 - mae: 0.0562
# Test MAE: 0.06060059368610382

# %%
from tensorflow.keras.models import load_model

# Load the saved model
model = load_model('aot_model.keras')

# Load the new dataset
new_df = pd.read_csv("datasets/test.csv")

# Preprocess numerical data
new_numerical_features = new_df[['elevation', 'ozone', 'NO2', 'azimuth', 'zenith', 'incidence_azimuth', 'incidence_zenith']]
new_numerical_features = scaler.transform(new_numerical_features)

# Load and preprocess new image data
new_image_data = np.array([load_and_preprocess_image(os.path.join('./test/', filename)) for filename in new_df['file_name_l1']])

# Predict values for the new data
predictions = model.predict([new_image_data, new_numerical_features])

# Save the predictions to a CSV file
results = pd.DataFrame({
    'id': new_df['id'],
    'value_550': predictions.flatten()
})
results.to_csv('predictions.csv', index=False)

print(results.head())
# Out:
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step
#    id  value_550
# 0   3   0.130956
# 1  25   0.124549
# 2  26   0.072042
# 3  27   0.195926
# 4  29   0.080565
